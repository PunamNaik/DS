# %%
import pandas as pd
path='C://users/naikp/Database/GlobalTemperatures.csv'
data=pd.read_csv(path)
data
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# 5     1750-06-01                  12.937                              1.724
# 6     1750-07-01                  15.868                              1.911
# 7     1750-08-01                  14.750                              2.231
# 8     1750-09-01                  11.413                              2.637
# 9     1750-10-01                   6.367                              2.668
# 10    1750-11-01                     NaN                                NaN
# ...

# %%
data.describe()
# Out:
#        LandAverageTemperature  LandAverageTemperatureUncertainty  \
# count             3180.000000                        3180.000000
# mean                 8.374731                           0.938468
# std                  4.381310                           1.096440
# min                 -2.080000                           0.034000
# 25%                  4.312000                           0.186750
# 50%                  8.610500                           0.392000
# 75%                 12.548250                           1.419250
# max                 19.021000                           7.880000
#
#        LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# count         1992.000000                    1992.000000         1992.000000
# mean            14.350601                       0.479782            2.743595
# std              4.309579                       0.583203            4.155835
# ...

# %%
import statistics

# %%
data['LandAverageTemperature'].describe()
# Out:
# count    3180.000000
# mean        8.374731
# std         4.381310
# min        -2.080000
# 25%         4.312000
# 50%         8.610500
# 75%        12.548250
# max        19.021000
# Name: LandAverageTemperature, dtype: float64

# %%
data['LandAverageTemperature'].describe(percentiles=[.10,.30,.65,.80])
# Out:
# count    3180.000000
# mean        8.374731
# std         4.381310
# min        -2.080000
# 10%         2.563900
# 30%         4.956700
# 50%         8.610500
# 65%        11.228700
# 80%        13.228400
# max        19.021000
# Name: LandAverageTemperature, dtype: float64

# %%
data['LandAverageTemperature'].mean()#avg value
# Out:
# 8.374731132075466

# %%
data['LandAverageTemperature'].cumsum() #cumulative sum
# Out:
# 0           3.034
# 1           6.117
# 2          11.743
# 3          20.233
# 4          31.806
# 5          44.743
# 6          60.611
# 7          75.361
# 8          86.774
# 9          93.141
# 10            NaN
# 11         95.913
# 12         98.408
# 13         99.371
# 14        105.171
# 15        112.841
# 16            NaN
# 17        126.668
# 18            NaN
# 19        141.073
# 20        151.746
# 21            NaN
# 22            NaN
# 23            NaN
# 24        152.094
# 25            NaN
# 26        157.900
# 27        166.165
# 28            NaN
# 29            NaN
#           ...
# 3162    26348.525
# 3163    26363.267
# 3164    26376.421
# 3165    26386.677
# 3166    26394.101
# 3167    26398.825
# 3168    26402.557
# 3169    26406.057
# 3170    26412.435
# 3171    26422.024
# 3172    26434.606
# 3173    26448.941
# 3174    26463.814
# 3175    26478.689
# 3176    26491.780
# 3177    26502.110
# 3178    26508.823
# 3179    26513.673
# 3180    26517.554
# ...

# %%
data['LandAverageTemperature'].max()
# Out:
# 19.021

# %%
data['LandAverageTemperature'].min()
# Out:
# -2.08

# %%
data['LandAverageTemperature'].sum()
# Out:
# 26631.644999999997

# %%
data['LandAverageTemperature'].sum(skipna=True)
# Out:
# 26631.644999999997

# %%
data['LandAverageTemperature'].sum(skipna=False)
# Out:
# nan

# %%
data['LandAverageTemperature'].median()#middle value
# Out:
# 8.610499999999998

# %%
data['LandAverageTemperature'].std()
# Out:
# 4.381309770725171

# %%
data['LandAverageTemperature'].count() #no. of non-na values
# Out:
# 3180

# %%
data.shape
# Out:
# (3192, 9)

# %%
data['LandAverageTemperature'].var()#variance
# Out:
# 19.19587530705185

# %%
#Covariance Matrix Of Values
data.cov()
# Out:
#                                            LandAverageTemperature  \
# LandAverageTemperature                                  19.195875
# LandAverageTemperatureUncertainty                       -0.980903
# LandMaxTemperature                                      18.295532
# LandMaxTemperatureUncertainty                           -0.269670
# LandMinTemperature                                      17.639358
# LandMinTemperatureUncertainty                           -0.318273
# LandAndOceanAverageTemperature                           5.366879
# LandAndOceanAverageTemperatureUncertainty               -0.041226
#
#                                            LandAverageTemperatureUncertainty  \
# LandAverageTemperature                                             -0.980903
# LandAverageTemperatureUncertainty                                   1.202180
# LandMaxTemperature                                                 -0.128316
# ...

# %%
#Correlation Matrix Of Values
data.corr()
# Out:
#                                            LandAverageTemperature  \
# LandAverageTemperature                                   1.000000
# LandAverageTemperatureUncertainty                       -0.204191
# LandMaxTemperature                                       0.995807
# LandMaxTemperatureUncertainty                           -0.108462
# LandMinTemperature                                       0.995611
# LandMinTemperatureUncertainty                           -0.167451
# LandAndOceanAverageTemperature                           0.988066
# LandAndOceanAverageTemperatureUncertainty               -0.131412
#
#                                            LandAverageTemperatureUncertainty  \
# LandAverageTemperature                                             -0.204191
# LandAverageTemperatureUncertainty                                   1.000000
# LandMaxTemperature                                                 -0.132905
# ...

# %%
#Kurtosis of preTestScore values
data['LandAverageTemperature'].kurt()
# Out:
# -1.3420724591854307

# %%
#Skewness of preTestScore values
data['LandAverageTemperature'].skew()
# Out:
# -0.08142566547693746
